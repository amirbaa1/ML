# %% [markdown]
# # import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib
# Out:
# Using matplotlib backend: QtAgg

# %% [markdown]
# ## read cvs

# %%
train = pd.read_csv("../data/diamonds_train.csv")

# %% [markdown]
# ## check data

# %%
train.describe()
# Out:
#               carat         depth         table         price             x  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.799444     61.753006     57.457830   3944.805440      5.734403
# std        0.475173      1.431088      2.232092   3997.938105      1.123077
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    951.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2410.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5351.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  50000.000000  50000.000000
# mean       5.737956      3.541056
# std        1.145579      0.707065
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
sb.pairplot(train)
plt.show()

# %% [markdown]
# # fix data outlier

# %% [markdown]
# ## find and remove outlier

# %%
train.drop(train.query("x==0 or y==0 or z==0").index,inplace=True)

# %%
train.describe()
# Out:
#               carat         depth         table         price             x  \
# count  49983.000000  49983.000000  49983.000000  49983.000000  49983.000000
# mean       0.799214     61.753088     57.457566   3943.076086      5.734869
# std        0.474970      1.430864      2.231614   3995.956857      1.120889
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    951.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2409.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5347.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  49983.000000  49983.000000
# mean       5.738302      3.542260
# std        1.143739      0.704162
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
train.drop(train.query("z>10 or y>10").index,inplace=True)

# %%
train.describe()
# Out:
#               carat         depth         table         price             x  \
# count  49977.000000  49977.000000  49977.000000  49977.000000  49977.000000
# mean       0.798979     61.753002     57.457566   3942.188307      5.734568
# std        0.474085      1.430676      2.231617   3994.659449      1.120323
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    951.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2409.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5347.000000      6.540000
# max        4.130000     79.000000     95.000000  18823.000000     10.020000
#
#                   y             z
# count  49977.000000  49977.000000
# mean       5.736457      3.541388
# std        1.112165      0.692019
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
train
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49976 rows x 10 columns]

# %%
sb.pairplot(train)

# %%
import plotly.express as px
df = px.data.tips()
fig = px.box(train,y="depth")
fig1 = px.box(train,y="table")
fig2 = px.box(train,y="carat")

fig1.show()
fig.show()
fig2.show()
# Out:
# <div>                            <div id="e0043dd4-8545-48ce-aba8-227d6da42001" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0043dd4-8545-48ce-aba8-227d6da42001")) {                    Plotly.newPlot(                        "e0043dd4-8545-48ce-aba8-227d6da42001",                        [{"alignmentgroup":"True","hovertemplate":"table=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[55.0,61.0,65.0,58.0,58.0,57.0,57.0,55.0,61.0,61.0,55.0,56.0,61.0,54.0,62.0,58.0,54.0,54.0,56.0,59.0,55.0,57.0,62.0,62.0,58.0,57.0,57.0,61.0,57.0,57.0,57.0,59.0,58.0,58.0,59.0,59.0,54.0,59.0,55.0,56.0,56.0,56.0,63.0,56.0,58.0,55.0,60.0,60.0,61.0,5
# ...

# %%
train.drop(train.query("table>80").index,inplace=True)

# %%
train_price = train['price']
train_price
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 49995    2757
# 49996    2757
# 49997    2757
# 49998    2757
# 49999    2757
# Name: price, Length: 49976, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train.to_numpy().reshape(-1,1),train_price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12736\664000242.py in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 model = LinearRegression()
# ----> 3 model.fit(train.to_numpy().reshape(-1,1),train_price)
#
# E:\Program Files (x86)\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# E:\Program Files (x86)\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# ...
